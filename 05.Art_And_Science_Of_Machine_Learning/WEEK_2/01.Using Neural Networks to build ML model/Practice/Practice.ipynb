# %% [markdown]
# # Enable Virtual Environment For This Notebook.

# %% [markdown]
# ### Activate Conda Environment

# %% [markdown]
# <b>`$ conda activate`</b>

# %% [markdown]
# ### Install Or Upgrade necessary software for virtual environment.

# %% [markdown]
# <b>`$ sudo apt-get install --upgrade python3-pip`</b>

# %% [markdown]
# <b>`$ sudo pip3 install --upgrade virtualenv`</b>

# %% [markdown]
# <b>`$ sudo pip3 install --upgrade setuptools`</b>

# %% [markdown]
# Now we will go to the location of the directory, where we will create our virtual environment.

# %% [markdown]
# <b>`$ cd /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model`</b>

# %% [markdown]
# ### Deactivate conda environment

# %% [markdown]
# <b>`$ conda deactivate`</b>

# %% [markdown]
# ### Create Virtual Environment

# %% [markdown]
# <b>`$ virtualenv Venv`</b>

# %% [markdown]
# ### Activate newly created virtual environment

# %% [markdown]
# <b>`$ source Venv/bin/activate`</b>

# %% [markdown]
# <b>`$ (Venv) which python`</b>

# %% [markdown]
# <b>`$ (Venv) pip list`</b>

# %% [markdown]
# <b>`$ (Venv) pip3 install jupyter`</b>

# %%
# %%writefile requirements.txt
# numpy
# pandas
# tensorflow==1.8.0
# Out:
# Overwriting requirements.txt

# %%
# %%bash
# pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from -r requirements.txt (line 1)) (1.18.2)
# Requirement already satisfied: pandas in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from -r requirements.txt (line 2)) (1.0.3)
# Requirement already satisfied: tensorflow==1.8.0 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from -r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from pandas->-r requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from pandas->-r requirements.txt (line 2)) (2019.3)
# Requirement already satisfied: absl-py>=0.1.6 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorflow==1.8.0->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: tensorboard<1.9.0,>=1.8.0 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorflow==1.8.0->-r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: grpcio>=1.8.6 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorflow==1.8.0->-r requirements.txt (line 3)) (1.27.2)
# Requirement already satisfied: six>=1.10.0 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorflow==1.8.0->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: protobuf>=3.4.0 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorflow==1.8.0->-r requirements.txt (line 3)) (3.11.3)
# Requirement already satisfied: astor>=0.6.0 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorflow==1.8.0->-r requirements.txt (line 3)) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorflow==1.8.0->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: gast>=0.2.0 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorflow==1.8.0->-r requirements.txt (line 3)) (0.3.3)
# Requirement already satisfied: wheel>=0.26 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorflow==1.8.0->-r requirements.txt (line 3)) (0.34.2)
# Requirement already satisfied: werkzeug>=0.11.10 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorboard<1.9.0,>=1.8.0->tensorflow==1.8.0->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorboard<1.9.0,>=1.8.0->tensorflow==1.8.0->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: html5lib==0.9999999 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorboard<1.9.0,>=1.8.0->tensorflow==1.8.0->-r requirements.txt (line 3)) (0.9999999)
# Requirement already satisfied: bleach==1.5.0 in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from tensorboard<1.9.0,>=1.8.0->tensorflow==1.8.0->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: setuptools in /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages (from protobuf>=3.4.0->tensorflow==1.8.0->-r requirements.txt (line 3)) (46.1.3)

# %%
# %%bash
# pip3 list
# Out:
# Package            Version
# ------------------ ---------
# absl-py            0.9.0
# astor              0.8.1
# attrs              19.3.0
# backcall           0.1.0
# bleach             1.5.0
# decorator          4.4.2
# defusedxml         0.6.0
# entrypoints        0.3
# gast               0.3.3
# grpcio             1.27.2
# html5lib           0.9999999
# importlib-metadata 1.6.0
# ipykernel          5.2.0
# ipython            7.13.0
# ipython-genutils   0.2.0
# ipywidgets         7.5.1
# jedi               0.16.0
# Jinja2             2.11.1
# jsonschema         3.2.0
# jupyter            1.0.0
# jupyter-client     6.1.2
# jupyter-console    6.1.0
# jupyter-core       4.6.3
# Markdown           3.2.1
# MarkupSafe         1.1.1
# mistune            0.8.4
# nbconvert          5.6.1
# nbformat           5.0.4
# notebook           6.0.3
# numpy              1.18.2
# pandas             1.0.3
# pandocfilters      1.4.2
# parso              0.6.2
# pexpect            4.8.0
# pickleshare        0.7.5
# pip                20.0.2
# prometheus-client  0.7.1
# prompt-toolkit     3.0.5
# protobuf           3.11.3
# ptyprocess         0.6.0
# Pygments           2.6.1
# pyrsistent         0.16.0
# python-dateutil    2.8.1
# pytz               2019.3
# pyzmq              19.0.0
# qtconsole          4.7.2
# QtPy               1.9.0
# Send2Trash         1.5.0
# setuptools         46.1.3
# six                1.14.0
# tensorboard        1.8.0
# tensorflow         1.8.0
# termcolor          1.1.0
# terminado          0.8.3
# testpath           0.4.4
# tornado            6.0.4
# traitlets          4.3.3
# wcwidth            0.1.9
# webencodings       0.5.1
# Werkzeug           1.0.0
# wheel              0.34.2
# widgetsnbextension 3.5.1
# zipp               3.1.0

# %%
# %%bash
# which python
# Out:
# /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/bin/python

# %%
# %%bash
# python --version
# Out:
# Python 3.6.9

# %% [markdown]
# <a>https://github.com/GoogleCloudPlatform/training-data-analyst/blob/master/courses/machine_learning/deepdive/05_artandscience/c_neuralnetwork.ipynb</a>

# %% [markdown]
# # Neural Network

# %% [markdown]
# **Learning Objectives:**
#   * Use the `DNNRegressor` class in TensorFlow to predict median housing price

# %% [markdown]
# The data is based on 1990 census data from California. This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.
# <p>
# Let's use a set of features to predict house value.

# %% [markdown]
# ## Set Up
# In this first cell, we'll load the necessary libraries.

# %%
import math
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format
print(tf.__version__)
# Out:
# /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /media/mujahid7292/Data/GoogleDriveSandCorp2014/ML_With_TensorFlow_On_GCP/05.Art_And_Science_Of_Machine_Learning/WEEK_2/01.Using Neural Networks to build ML model/Venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.8.0

# %%
# %%bash
# ls
# Out:
# california_housing_train.csv
# Practice.ipynb
# requirements.txt

# %% [markdown]
# Next, we'll load our data set.

# %%
df = pd.read_csv('./california_housing_train.csv', sep=",")

# %% [markdown]
# ## Examine the data
#
# It's a good idea to get to know your data a little bit before you work with it.
#
# We'll print out a quick summary of a few useful statistics on each column.
#
# This will include things like mean, standard deviation, max, min, and various quantiles.

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5             66900.0
# 1      1129.0       463.0            1.8             80100.0
# 2       333.0       117.0            1.7             85700.0
# 3       515.0       226.0            3.2             73400.0
# 4       624.0       262.0            1.9             65500.0

# %%
df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# min           3.0         1.0            0.5             14999.0
# 25%         790.0       282.0            2.6            119400.0
# 50%        1167.0       409.0            3.5            180400.0
# 75%        1721.0       605.2            4.8            265000.0
# max       35682.0      6082.0           15.0            500001.0

# %% [markdown]
# This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.  Let's create a different, more appropriate feature.  Because we are predicting the price of a single house, we should try to make all our features correspond to a single house as well

# %%
df['num_rooms'] = df['total_rooms'] / df['households']
df['num_bedrooms'] = df['total_bedrooms'] / df['households']
df['persons_per_house'] = df['population'] / df['households']
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  num_rooms  \
# 0      1015.0       472.0            1.5             66900.0       11.9
# 1      1129.0       463.0            1.8             80100.0       16.5
# 2       333.0       117.0            1.7             85700.0        6.2
# 3       515.0       226.0            3.2             73400.0        6.6
# 4       624.0       262.0            1.9             65500.0        5.5
#
#    num_bedrooms  persons_per_house
# 0           2.7                2.2
# 1           4.1                2.4
# 2           1.5                2.8
# 3           1.5                2.3
# 4           1.2                2.4

# %% [markdown]
# Now we will drop unnecessary column from our dataset.

# %%
df.drop(
    labels=['total_rooms','total_bedrooms','population','households'],
    axis=1,
    inplace=True
)
df.head()
# Out:
#    longitude  latitude  housing_median_age  median_income  median_house_value  \
# 0     -114.3      34.2                15.0            1.5             66900.0
# 1     -114.5      34.4                19.0            1.8             80100.0
# 2     -114.6      33.7                17.0            1.7             85700.0
# 3     -114.6      33.6                14.0            3.2             73400.0
# 4     -114.6      33.6                20.0            1.9             65500.0
#
#    num_rooms  num_bedrooms  persons_per_house
# 0       11.9           2.7                2.2
# 1       16.5           4.1                2.4
# 2        6.2           1.5                2.8
# 3        6.6           1.5                2.3
# 4        5.5           1.2                2.4

# %% [markdown]
# ## Build a neural network model
#
# In this exercise, we'll be trying to predict `median_house_value`. It will be our label (sometimes also called a target). We'll use the remaining columns as our input features.
#
# To train our model, we'll first use the [LinearRegressor](https://www.tensorflow.org/api_docs/python/tf/contrib/learn/LinearRegressor) interface. Then, we'll change to DNNRegressor

# %%
featcols = {
    colname:tf.feature_column.numeric_column(key=colname) \
    for colname in 'housing_median_age,median_income,num_rooms,num_bedrooms,persons_per_house'.split(',')
}

# Now we will bucketize our latitude and longitude so that it is not so in high-res.
# California is mostly North-South, so more lats than lons
featcols['longitude'] = tf.feature_column.bucketized_column(
    source_column=tf.feature_column.numeric_column('longitude'),
    boundaries=np.linspace(start=-124.3, stop=-114.3, num=5).tolist()
)

featcols['latitude'] = tf.feature_column.bucketized_column(
    source_column=tf.feature_column.numeric_column('latitude'),
    boundaries=np.linspace(start=32.5, stop=42, num=10).tolist()
)

# %%
featcols.keys()
# Out:
# dict_keys(['housing_median_age', 'median_income', 'num_rooms', 'num_bedrooms', 'persons_per_house', 'longitude', 'latitude'])

# %% [markdown]
# ## Split the dataset into training and evaluation

# %%
msk = np.random.randn(len(df)) < 0.8
train_df = df[msk] # Put 80% data in training
eval_df = df[~msk] # Put 20% data in evaluation
print('Training Size: {}'.format(train_df.size))
print('Evaluation Size: {}'.format(eval_df.size))
# Out:
# Training Size: 106664
# Evaluation Size: 29336

# %% [markdown]
# ## Constant Of Our Training

# %%
SCALE = 100000 # 1 Lac
BATCH_SIZE = 100
OUTDIR = './house_trained'

# %% [markdown]
# ## Create training and evaluation input function

# %%
train_input_fn  = tf.estimator.inputs.pandas_input_fn(
    x=train_df[list(featcols.keys())],
    y=train_df['median_house_value'] / SCALE, # Note the scalling
    batch_size=BATCH_SIZE,
    num_epochs=None,
    shuffle=True
)

eval_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=eval_df[list(featcols.keys())],
    y=eval_df['median_house_value'] / SCALE, # Note the scalling
    num_epochs=1,
    batch_size=len(eval_df),
    shuffle=False
)

print('Features List = {}'.format(list(featcols.keys())))
# Out:
# Features List = ['housing_median_age', 'median_income', 'num_rooms', 'num_bedrooms', 'persons_per_house', 'longitude', 'latitude']

# %% [markdown]
# ## Linear Regressor

# %%
def train_and_evaluate(output_dir, num_train_steps):
    """
    """
    # Creat Optimizer 
    myopt = tf.train.FtrlOptimizer(learning_rate=0.01) # Note the learning rate
    
    # Create Linear Regressor Estimator Object
    estimator = tf.estimator.LinearRegressor(
        feature_columns=featcols.values(),
        model_dir=output_dir,
        optimizer=myopt
    )
    
    # Create a custom evaluation metric
    def rmse(labels, predictions):
        """
        """
        pred_value = tf.cast(x=predictions['predictions'],dtype=tf.float64)
        return {'rmse': tf.metrics.root_mean_squared_error(labels,pred_value)}
    
    # Attach avobe custom evaluation metric with our esimator object
    estimator = tf.contrib.estimator.add_metrics(estimator,rmse)
    
    # Create training specification
    train_spec = tf.estimator.TrainSpec(
        input_fn=train_input_fn,
        max_steps=num_train_steps
    )
    
    # Create evaluation specification
    eval_spec = tf.estimator.EvalSpec(
        input_fn=eval_input_fn,
        steps=None,
        start_delay_secs=1, # Start evaluating after N seconds
        throttle_secs=10 # Evaluate every N seconds
    )
    
    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# %% [markdown]
# ## Now run the training using Linear Regressor

# %%
shutil.rmtree(path=OUTDIR, ignore_errors=True) # Start fresh every time
train_and_evaluate(OUTDIR, num_train_steps = (100 * len(train_df)) / BATCH_SIZE)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './house_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fccb2a1cd68>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': './house_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fccb2a1ca20>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 10 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into 
_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 49.611847.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-03-29-05:58:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./house_trained/model.ckpt-13333
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-03-29-05:58:53
# INFO:tensorflow:Saving dict for global step 13333: average_loss = 0.57098776, global_step = 13333, loss = 2093.812, rmse = 0.75563735

# %% [markdown]
# ## DNN Regressor

# %%
def train_and_evalaute_dnn(ouput_dir, num_train_steps):
    """
    """
    # Create custom optimizer
    myopt = tf.train.FtrlOptimizer(learning_rate=0.01) # Note the learning rate
    
    # Create DNN Regressor estimator object
    estimator = tf.estimator.DNNRegressor(
        hidden_units=[100, 50, 20],
        feature_columns=featcols.values(),
        model_dir=ouput_dir,
        optimizer=myopt,
        dropout=0.10
    )
    
    # Create custom evaluation metric
    def rmse(labels, predictions):
        """
        """
        pred_values = tf.cast(predictions['predictions'], tf.float64)
        return {'rmse' : tf.metrics.root_mean_squared_error(labels,pred_values)}
    
    # Attach custom estimator with the estimator object
    estimator = tf.contrib.estimator.add_metrics(estimator, rmse)
    
    # Create training specification
    train_spec = tf.estimator.TrainSpec(
        input_fn=train_input_fn,
        max_steps=num_train_steps
    )
    
    # Create evaluation specefication
    eval_spec = tf.estimator.EvalSpec(
        input_fn=eval_input_fn,
        steps=None,
        start_delay_secs=1, # Start after N seconds
        throttle_secs=10 # Evaluate every N seconds
    )
    
    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# %% [markdown]
# ## Now run the training using DNN Regressor

# %%
shutil.rmtree(OUTDIR, ignore_errors=True) # Start fresh every time
tf.summary.FileWriterCache.clear() # ensure filewriter cache is clear for TensorBoard events file
train_and_evalaute_dnn(OUTDIR, num_train_steps = (100 * len(train_df)) / BATCH_SIZE)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './house_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcc77a199b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': './house_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcc77a192e8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 10 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ./house_trained/model.ckpt.
# INFO:tensorflow:loss = 558.32935, step = 1
# INFO:tensorflow:global_step/sec: 317.244
# INFO:tensorflow:loss = 97.882965, step = 101 (0.319 sec)
# INFO:tensorflow:global_step/sec: 503.721
# INFO:tensorflow:loss = 78.955414, step = 201 (0.197 sec)
# INFO:tensorflow:global_step/sec: 497.497
# INFO:tensorflow:loss = 68.403465, step = 301 (0.202 sec)
# INFO:tensorflow:global_step/sec: 488.942
# INFO:tensorflow:loss = 38.637745, step = 401 (0.204 sec)
# INFO:tensorflow:global_step/sec: 490.584
# INFO:tensorflow:loss = 150.82106, step = 501 (0.203 sec)
# INFO:tensorflow:global_step/sec: 503.058
# INFO:tensorflow:loss = 62.27884, step = 601 (0.199 sec)
# INFO:tensorflow:global_step/sec: 499.94
# INFO:tensorflow:loss = 38.304195, step = 701 (0.201 sec)
# INFO:tensorflow:global_step/sec: 501.456
# INFO:tensorflow:loss = 40.677643, step = 801 (0.198 sec)
# INFO:tensorflow:global_step/sec: 383.743
# INFO:tensorflow:loss = 132.02168, step = 901 (0.266 sec)
# INFO:tensorflow:global_step/sec: 485.51
# INFO:tensorflow:loss = 48.695236, step = 1001 (0.202 sec)
# INFO:tensorflow:global_step/sec: 492.419
# INFO:tensorflow:loss = 33.151787, step = 1101 (0.203 sec)
# INFO:tensorflow:global_step/sec: 493.049
# INFO:tensorflow:loss = 46.109676, step = 1201 (0.203 sec)
# INFO:tensorflow:global_step/sec: